# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Series : array or list
#
# ## DataFrame : 試算表的表格

# %%
# %ls  #看現在路徑下有甚麼東西的魔術指令
# Out:
#  磁碟區 C 中的磁碟是 Local Disk
#  磁碟區序號:  0671-FAEA
#
#  C:\Users\victorialee\Desktop\span\MyWork 的目錄
# 找不到檔案

# %%
#讀取csv的方法 : pd.read_csv("檔名") 
# ex.pd.read_csv("grades.csv")

# %%
#看dataframe前五行資料的方法 : dataframe的名稱.head()

# %%
#統計數據大補帖 : dataframe名稱.describe()

# %%
#算相關係數 : dataframe名稱.corr()
#算特定兩個項的相關係數 : dataframe名稱.A項.corr(dataframe名稱.B項)

# %%
#新增一個總和的欄位: df名稱["新增欄位名稱"]=df[要總和的欄位的List].sum(1)

# %%
#新增一個經過計算的欄位 : df名稱["新增欄位名稱"]=df名稱.項目 計算式

# %%
#依項目進行排序

#大到小
#df名稱.sort_values(by= '要排序項目'.ascending=False)

#小到大
#df名稱.sort_values(by= '要排序項目')

# %%
#多個項目進行排序

#df名稱.sort_values(by= ['要排序項目1','要排序項目2',... ])

# %% [markdown]
# # 自己作dataframe

# %%
mydata = np.random.randn(4,3)

# %%
mydata
# Out:
# array([[-0.55159827,  0.43366354, -1.28028039],
#        [-0.70154514,  1.52686116,  1.40994482],
#        [ 1.5375358 , -1.37272293, -0.29157108],
#        [-0.93991032, -0.04840375, -0.73029016]])

# %%
list("ABCDE") #把一個字串變成list : list("字串")
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
df1 = pd.DataFrame(mydata, columns=list("ABC"))

#自訂dataframe:新dataframe=pd.DataFrame(array, columns=項目list)

# %%
df1
# Out:
#           A         B         C
# 0 -0.551598  0.433664 -1.280280
# 1 -0.701545  1.526861  1.409945
# 2  1.537536 -1.372723 -0.291571
# 3 -0.939910 -0.048404 -0.730290

# %%
df2 = pd.DataFrame(np.random.randn(3,3), columns=list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0  0.454368 -0.235746 -0.166343
# 1  0.466889 -0.447396  0.342442
# 2  0.320038  0.417774 -1.091060

# %%
df3 = pd.concat([df1,df2], axis=0, )  #pd.concat:df合併

#新df=pd.concat(dataframe的list, axis=0) #axis控制合併的方向─ 0是上下(列方向)，1是左右(行方向)

# %%
df3
# Out:
#           A         B         C
# 0 -0.551598  0.433664 -1.280280
# 1 -0.701545  1.526861  1.409945
# 2  1.537536 -1.372723 -0.291571
# 3 -0.939910 -0.048404 -0.730290
# 0  0.454368 -0.235746 -0.166343
# 1  0.466889 -0.447396  0.342442
# 2  0.320038  0.417774 -1.091060

# %%
df3.index=range(7)  #更改df的index :df名稱.index=要給的list

# %%
df3
# Out:
#           A         B         C
# 0 -0.551598  0.433664 -1.280280
# 1 -0.701545  1.526861  1.409945
# 2  1.537536 -1.372723 -0.291571
# 3 -0.939910 -0.048404 -0.730290
# 4  0.454368 -0.235746 -0.166343
# 5  0.466889 -0.447396  0.342442
# 6  0.320038  0.417774 -1.091060

# %%
df4=pd.concat([df1,df2],axis=1)

# %%
df4
# Out:
#           A         B         C         A         B         C
# 0 -0.551598  0.433664 -1.280280  0.454368 -0.235746 -0.166343
# 1 -0.701545  1.526861  1.409945  0.466889 -0.447396  0.342442
# 2  1.537536 -1.372723 -0.291571  0.320038  0.417774 -1.091060
# 3 -0.939910 -0.048404 -0.730290       NaN       NaN       NaN

# %% [markdown]
# # pandas的學習資源

# %% [markdown]
# [pandas學習資源]https://github.com/justmarkham/pandas-videos

# %%
df = pd.read_csv("http://bit.ly/uforeports")  #csv也可以是網址

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df_state = df.groupby("State").count()

#依項目集合值: dataframe名稱.groupby(項目)
#計算次數: dataframe名稱.count()

# %%
df_state
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529
# CO      367               60             322   367
# CT      225               25             188   225
# Ca        1                0               1     1
# DE       43                5              38    43
# FL      835              120             727   837
# Fl        4                1               0     4
# GA      325               44             294   325
# HI       85               16              74    85
# IA      162               28             142   162
# ID      130               12             109   130
# IL      612              112             540   613
# IN      326               49             296   326
# ...

# %%
df_state.sort_values(by="Time", ascending=False)
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591
# OR      534               89             414   534
# MO      448               86             386   448
# NJ      370               51             326   370
# CO      367               60             322   367
# WI      357               63             312   357
# NC      356               55             325   356
# IN      326               49             296   326
# ...

# %%
df_state
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# AK      116               25              99   116
# AL      193               21             173   193
# AR      206               26             186   206
# AZ      736              145             644   738
# CA     2525              457            2148  2529
# CO      367               60             322   367
# CT      225               25             188   225
# Ca        1                0               1     1
# DE       43                5              38    43
# FL      835              120             727   837
# Fl        4                1               0     4
# GA      325               44             294   325
# HI       85               16              74    85
# IA      162               28             142   162
# ID      130               12             109   130
# IL      612              112             540   613
# IN      326               49             296   326
# ...

# %%
df_state.sort_values(by="Time", ascending=False, inplace=True)

#sort不產生新的df的方法 : inplace=True

# %%
df_state
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591
# OR      534               89             414   534
# MO      448               86             386   448
# NJ      370               51             326   370
# CO      367               60             322   367
# WI      357               63             312   357
# NC      356               55             325   356
# IN      326               49             296   326
# ...

# %%
df_state.head(10)
# Out:
#        City  Colors Reported  Shape Reported  Time
# State
# CA     2525              457            2148  2529
# WA     1320              269             925  1322
# TX     1025              138             923  1027
# NY      913              123             823   914
# FL      835              120             727   837
# AZ      736              145             644   738
# OH      665               93             605   667
# IL      612              112             540   613
# PA      598               97             519   598
# MI      590               78             504   591

# %%
df_state[:10].Time.plot(kind='bar') #畫長條圖:df名稱.項目.plot(kind='bar')

# %%
df= pd.DataFrame(np.random.randn(5,3), index=list(range(1,6)), columns=list("ABC"))

# %%
df
# Out:
#           A         B         C
# 1 -1.208203  0.656661  0.921402
# 2 -1.053599 -1.031223 -0.580516
# 3 -0.437522  0.210381 -0.642762
# 4 -0.928282 -0.479562 -0.079193
# 5  0.593375  0.516491  1.363018

# %%
df[df.B>0]
# Out:
#           A         B         C
# 1 -1.208203  0.656661  0.921402
# 3 -0.437522  0.210381 -0.642762
# 5  0.593375  0.516491  1.363018

# %%
df[df.B>0]["C"]=0 #若B>0 把C變成0
# Out:
# C:\Users\victorialee\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.loc[2:3, "B":"C"]
# Out:
#           B         C
# 2 -1.031223 -0.580516
# 3  0.210381 -0.642762

# %%
df.loc[2, "B"]
# Out:
# -1.031223491221061

# %%
df.loc[2,"B"]=1

# %%
df
# Out:
#           A         B         C
# 1 -1.208203  0.656661  0.921402
# 2 -1.053599  1.000000 -0.580516
# 3 -0.437522  0.210381 -0.642762
# 4 -0.928282 -0.479562 -0.079193
# 5  0.593375  0.516491  1.363018

# %%
df.loc[df.B>0, "C"]=0

# %%
df
# Out:
#           A         B         C
# 1 -1.208203  0.656661  0.000000
# 2 -1.053599  1.000000  0.000000
# 3 -0.437522  0.210381  0.000000
# 4 -0.928282 -0.479562 -0.079193
# 5  0.593375  0.516491  0.000000

# %% [markdown]
# # 安裝 pandas-datareader
#
# ### 注意要安裝 pandas-datareader 套件
# ####     conda install pandas-reader  (在終端機輸入)
#
# ### 如果之前裝過，但有陣子沒用記得更新
# ####   conda update pandas-reader

# %%
import pandas_datareader.data as web

# %%
df = web.DataReader("AAPL", "yahoo", start="2012-9-1", end="2017-8-31")  
# ("想讀的股票代號", "從哪讀", start="哪天開始", end="哪天結束")

# %%
df.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2012-08-31  95.514282  93.892860  95.321426  95.034286  84580300.0  83.293762
# 2012-09-04  96.448570  94.928574  95.108574  96.424286  91973000.0  84.512062
# 2012-09-05  96.621429  95.657143  96.510002  95.747147  84093800.0  83.918564
# 2012-09-06  96.898575  95.828575  96.167145  96.610001  97799100.0  84.674820
# 2012-09-07  97.497147  96.538574  96.864288  97.205711  82416600.0  85.196938

# %%
P = df["Adj Close"] #只要某個column的資料

# %%
P.head()
# Out:
# Date
# 2012-08-31    83.293762
# 2012-09-04    84.512062
# 2012-09-05    83.918564
# 2012-09-06    84.674820
# 2012-09-07    85.196938
# Name: Adj Close, dtype: float64

# %%
P.plot()

# %% [markdown]
# ## 計算報酬率

# %%
r= P.diff()/P  #diff:跟前一期的差別

# %%
r[-100:].plot()

# %% [markdown]
# ### 做移動平均

# %%
P.rolling(window=20).mean()  #20天的小視窗
# Out:
# Date
# 2012-08-31           NaN
# 2012-09-04           NaN
# 2012-09-05           NaN
# 2012-09-06           NaN
# 2012-09-07           NaN
# 2012-09-10           NaN
# 2012-09-11           NaN
# 2012-09-12           NaN
# 2012-09-13           NaN
# 2012-09-14           NaN
# 2012-09-17           NaN
# 2012-09-18           NaN
# 2012-09-19           NaN
# 2012-09-20           NaN
# 2012-09-21           NaN
# 2012-09-24           NaN
# 2012-09-25           NaN
# 2012-09-26           NaN
# 2012-09-27           NaN
# 2012-09-28     85.236008
# 2012-10-01     85.199384
# 2012-10-02     85.113866
# 2012-10-03     85.121505
# 2012-10-04     85.062218
# 2012-10-05     84.887865
# 2012-10-08     84.734046
# 2012-10-09     84.579163
# 2012-10-10     84.398362
# 2012-10-11     84.054789
# 2012-10-12     83.669333
#                  ...
# 2017-07-21    141.473157
# 2017-07-24    141.753854
# 2017-07-25    142.088181
# 2017-07-26    142.558267
# 2017-07-27    142.786788
# ...

# %%
P.plot()
P.rolling(window=20).mean().plot()
P.rolling(window=60).mean().plot()
